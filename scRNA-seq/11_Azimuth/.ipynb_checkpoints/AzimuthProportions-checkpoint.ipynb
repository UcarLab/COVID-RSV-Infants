# %%
import pandas as pd
import numpy as np
import scanpy as sc
import scanpy.external as sce
from matplotlib.pyplot import rc_context
import matplotlib.pyplot as plt
import seaborn as sb

# %%
sc.set_figure_params(dpi=300, dpi_save=300, vector_friendly=True, color_map = 'viridis')
sc.settings.verbosity = 3

# %%
adata = sc.read("/Users/athib/Desktop/CovidRSV/scRNA2/COVIDRSV_Pass2_Cleaned.h5ad")

# %%
azimuthannotations = pd.read_csv("/Users/athib/Desktop/CovidRSV/scRNA2/AzimuthPredictions.csv", index_col=0)

# %%
azimuthannotations = azimuthannotations.reindex(adata.obs.index)

# %%
azimuthannotations['Annotation'] = adata.obs['Annotation'].copy()

# %%
azimuthlabels
# Out:
# array(['ASDC', 'B intermediate', 'B memory', 'B naive', 'CD14 Mono',
#        'CD16 Mono', 'CD4 Naive', 'CD4 Proliferating', 'CD4 TCM',
#        'CD4 TEM', 'CD8 Naive', 'CD8 Proliferating', 'CD8 TCM', 'CD8 TEM',
#        'Eryth', 'HSPC', 'ILC', 'MAIT', 'NK', 'NK Proliferating',
#        'NK_CD56bright', 'Plasmablast', 'Platelet', 'Treg', 'cDC1', 'cDC2',
#        'dnT', 'gdT', 'pDC'], dtype=object)

# %%
azimuthlabels = ['B naive',
                'B intermediate',
                'B memory',
                'Plasmablast',
                'CD4 Naive',
                'CD4 TCM',
                'CD4 TEM',
                'Treg',
                'CD8 Naive',
                'CD8 TCM',
                'CD8 TEM',
                'dnT',
                'MAIT',
                'gdT',
                'CD4 Proliferating',
                'CD8 Proliferating', 
                'NK', 
                'NK_CD56bright',
                'NK Proliferating',
                'CD14 Mono',
                'CD16 Mono',
                'cDC1', 
                'cDC2',
                'ASDC', 
                'pDC',
                'Eryth',
                'HSPC',
                'ILC',
                'Platelet'
                ]

# %%
annotationslabels = ['Naive B',
                    'ISG+ B',
                    'TXNIP+ B',
                    'TrB',
                    'ISG+ TrB',
                    'Memory B',
                    'AIM2+ Memory B',
                    'CD24- B',
                    'PC',
                    'Naive CD4+ T',
                    'ISG+ CD4+ T',
                    'CD4+ TCM',
                    'CD4+ TEM',
                    'ZBTB16+ CD4+ T',
                    'Naive Treg',
                    'TIGIT+ Treg',
                    'Memory Treg',
                    'ISG+ Treg',
                    'Naive CD8+ T',
                    'ISG+ CD8+ T',
                    'GZMK+ T',
                    'CCL5+ GZMK+ T',
                    'S100+ GZMK+ T',
                    'MAIT',
                    'Temra',
                    'γδ T',
                    'CD8+ γδ T',
                    'Prolif/Cycling Cytotoxic T',
                    'Cytotoxic C8',
                    'Prolif/Cycling T',
                    'CD16+ NK',
                    'CD56+ NK',
                    'Prolif/Cycling NK',
                    'CD14+ Monocyte',
                    'S100+ CD14+ Monocyte',
                    'ISG+ CD14+ Monocyte',
                    'CD163+ Monocyte',
                    'CD16+ Monocyte',
                    'ISG+ CD16+ Monocyte',
                    'Mo-DC',
                    'cDC1',
                    'cDC2',
                    'AXL+ SIGLEC6+ DC',
                    'pDC',
                    'Erythroblast',
                    'HSC',
                    'ILC-like',
                    'MGK']

# %%
numazimuth = len(azimuthlabels)
numannotation = len(annotationslabels)

# %%
matrix = np.zeros((numannotation, numazimuth))

# %%
indexi = 0
for curannotation in annotationslabels:
    indexj = 0
    curannotationnum =  sum(azimuthannotations['Annotation'] == curannotation)
    print(curannotation)
    for curazimuth in azimuthlabels:
        curazimuthnum =  sum( (azimuthannotations['x'] == curazimuth) & (azimuthannotations['Annotation'] == curannotation) )
        matrix[indexi, indexj] = curazimuthnum/curannotationnum
        indexj += 1
    indexi += 1
# Out:
# Naive B
# ISG+ B
# TXNIP+ B
# TrB
# ISG+ TrB
# Memory B
# AIM2+ Memory B
# CD24- B
# PC
# Naive CD4+ T
# ISG+ CD4+ T
# CD4+ TCM
# CD4+ TEM
# ZBTB16+ CD4+ T
# Naive Treg
# TIGIT+ Treg
# Memory Treg
# ISG+ Treg
# Naive CD8+ T
# ISG+ CD8+ T
# GZMK+ T
# CCL5+ GZMK+ T
# S100+ GZMK+ T
# MAIT
# Temra
# γδ T
# CD8+ γδ T
# Prolif/Cycling Cytotoxic T
# Cytotoxic C8
# Prolif/Cycling T
# CD16+ NK
# CD56+ NK
# Prolif/Cycling NK
# CD14+ Monocyte
# S100+ CD14+ Monocyte
# ISG+ CD14+ Monocyte
# CD163+ Monocyte
# CD16+ Monocyte
# ISG+ CD16+ Monocyte
# Mo-DC
# cDC1
# cDC2
# AXL+ SIGLEC6+ DC
# pDC
# Erythroblast
# HSC
# ILC-like
# MGK

# %%
newdf = pd.DataFrame(matrix, index=annotationslabels, columns=azimuthlabels)

# %%
newdf
# Out:
#                              B naive  B intermediate  B memory  Plasmablast  \
# Naive B                     0.863508        0.136301  0.000191     0.000000
# ISG+ B                      0.967312        0.032688  0.000000     0.000000
# TXNIP+ B                    0.795480        0.204520  0.000000     0.000000
# TrB                         0.983271        0.016729  0.000000     0.000000
# ISG+ TrB                    0.994949        0.005051  0.000000     0.000000
# Memory B                    0.188212        0.804709  0.007079     0.000000
# AIM2+ Memory B              0.013348        0.380423  0.598443     0.006674
# CD24- B                     0.007067        0.992933  0.000000     0.000000
# PC                          0.000000        0.002096  0.000000     0.974843
# Naive CD4+ T                0.000000        0.000000  0.000000     0.000000
# ISG+ CD4+ T                 0.000000        0.000000  0.000000     0.000000
# CD4+ TCM                    0.000000        0.000000  0.000000     0.000000
# CD4+ TEM                    0.000000        0.000000  0.000000     0.000000
# ZBTB16+ CD4+ T              0.000000        0.000000  0.000000     0.000000
# Naive Treg                  0.000000        0.000000  0.000000     0.000000
# TIGIT+ Treg                 0.000000        0.000000  0.000000     0.000000
# Memory Treg                 0.000000        0.000000  0.000000     0.000000
# ISG+ Treg                   0.000000        0.000000  0.000000     0.000000
# Naive CD8+ T                0.000000        0.000000  0.000000     0.000000
# ISG+ CD8+ T                 0.000000        0.000000  0.000000     0.000000
# GZMK+ T                     0.000000        0.000000  0.000000     0.000000
# CCL5+ GZMK+ T               0.000000        0.000000  0.000000     0.000000
# S100+ GZMK+ T               0.000000        0.000000  0.000000     0.000000
# MAIT                        0.000000        0.000000  0.000000     0.000000
# Temra                       0.000000        0.000000  0.000000     0.000000
# γδ T                        0.000000        0.000000  0.000000     0.000000
# CD8+ γδ T                   0.000000        0.000000  0.000000     0.000000
# Prolif/Cycling Cytotoxic T  0.000000        0.000000  0.000000     0.000000
# Cytotoxic C8                0.000000        0.000000  0.000000     0.000000
# Prolif/Cycling T            0.000000        0.000000  0.000000     0.000000
# CD16+ NK                    0.000000        0.000000  0.000000     0.000000
# CD56+ NK                    0.000000        0.000000  0.000000     0.000000
# Prolif/Cycling NK           0.000000        0.000000  0.000000     0.000000
# CD14+ Monocyte              0.000000        0.000000  0.000000     0.000000
# S100+ CD14+ Monocyte        0.000000        0.000000  0.000000     0.000000
# ISG+ CD14+ Monocyte         0.000000        0.000000  0.000000     0.000000
# CD163+ Monocyte             0.000000        0.000000  0.000000     0.000000
# CD16+ Monocyte              0.000000        0.000000  0.000000     0.000000
# ISG+ CD16+ Monocyte         0.000000        0.000000  0.000000     0.000000
# Mo-DC                       0.000000        0.000000  0.000000     0.000000
# cDC1                        0.000000        0.000000  0.000000     0.000000
# cDC2                        0.000000        0.000000  0.000000     0.000000
# AXL+ SIGLEC6+ DC            0.000000        0.000000  0.000000     0.000000
# pDC                         0.000000        0.000000  0.000000     0.000000
# Erythroblast                0.080460        0.017241  0.005747     0.000000
# HSC                         0.000000        0.000000  0.000000     0.000000
# ILC-like                    0.000000        0.000000  0.000000     0.000000
# MGK                         0.000000        0.000000  0.000000     0.000000
#
#                             CD4 Naive   CD4 TCM   CD4 TEM      Treg  \
# Naive B                      0.000000  0.000000  0.000000  0.000000
# ISG+ B                       0.000000  0.000000  0.000000  0.000000
# TXNIP+ B                     0.000000  0.000000  0.000000  0.000000
# TrB                          0.000000  0.000000  0.000000  0.000000
# ISG+ TrB                     0.000000  0.000000  0.000000  0.000000
# Memory B                     0.000000  0.000000  0.000000  0.000000
# AIM2+ Memory B               0.000000  0.000000  0.000000  0.000000
# CD24- B                      0.000000  0.000000  0.000000  0.000000
# PC                           0.000000  0.018868  0.000000  0.000000
# Naive CD4+ T                 0.327458  0.667236  0.000015  0.000419
# ISG+ CD4+ T                  0.032524  0.966525  0.000000  0.000063
# CD4+ TCM                     0.015484  0.980457  0.000000  0.000601
# CD4+ TEM                     0.000000  0.986777  0.002938  0.002204
# ZBTB16+ CD4+ T               0.000000  0.944236  0.008323  0.000416
# Naive Treg                   0.039057  0.553560  0.000000  0.398484
# TIGIT+ Treg                  0.000000  0.355179  0.000000  0.641431
# Memory Treg                  0.000000  0.770707  0.000000  0.225253
# ISG+ Treg                    0.000000  0.981840  0.000000  0.018160
# Naive CD8+ T                 0.007173  0.022232  0.000076  0.000102
# ISG+ CD8+ T                  0.000717  0.426045  0.000000  0.000000
# GZMK+ T                      0.000000  0.106838  0.004274  0.000855
# CCL5+ GZMK+ T                0.000000  0.175124  0.024876  0.000000
# S100+ GZMK+ T                0.000000  0.026316  0.000000  0.000000
# MAIT                         0.000000  0.005980  0.000000  0.000000
# Temra                        0.000000  0.007931  0.000000  0.000000
# γδ T                         0.003253  0.051647  0.000000  0.000000
# CD8+ γδ T                    0.000000  0.013793  0.000000  0.000000
# Prolif/Cycling Cytotoxic T   0.000000  0.049322  0.000000  0.000000
# Cytotoxic C8                 0.000000  0.002119  0.000000  0.000000
# Prolif/Cycling T             0.087183  0.581967  0.000000  0.000000
# CD16+ NK                     0.000000  0.000120  0.000000  0.000000
# CD56+ NK                     0.000000  0.001479  0.000000  0.000000
# Prolif/Cycling NK            0.000000  0.000000  0.000000  0.000000
# CD14+ Monocyte               0.000000  0.000000  0.000000  0.000000
# S100+ CD14+ Monocyte         0.000000  0.000000  0.000000  0.000000
# ISG+ CD14+ Monocyte          0.000000  0.000000  0.000000  0.000000
# CD163+ Monocyte              0.000000  0.000000  0.000000  0.000000
# CD16+ Monocyte               0.000000  0.000000  0.000000  0.000000
# ISG+ CD16+ Monocyte          0.000000  0.000000  0.000000  0.000000
# Mo-DC                        0.000000  0.000000  0.000000  0.000000
# cDC1                         0.000000  0.000000  0.000000  0.000000
# cDC2                         0.000000  0.000000  0.000000  0.000000
# AXL+ SIGLEC6+ DC             0.000000  0.000000  0.000000  0.000000
# pDC                          0.000000  0.000000  0.000000  0.000000
# Erythroblast                 0.011494  0.114943  0.000000  0.000000
# HSC                          0.000000  0.000000  0.000000  0.000000
# ILC-like                     0.000000  0.070796  0.000000  0.000000
# MGK                          0.000000  0.000000  0.000000  0.000000
#
#                             CD8 Naive   CD8 TCM  ...  CD14 Mono  CD16 Mono  \
# Naive B                      0.000000  0.000000  ...   0.000000   0.000000
# ISG+ B                       0.000000  0.000000  ...   0.000000   0.000000
# TXNIP+ B                     0.000000  0.000000  ...   0.000000   0.000000
# TrB                          0.000000  0.000000  ...   0.000000   0.000000
# ISG+ TrB                     0.000000  0.000000  ...   0.000000   0.000000
# Memory B                     0.000000  0.000000  ...   0.000000   0.000000
# AIM2+ Memory B               0.000000  0.000000  ...   0.000000   0.000000
# CD24- B                      0.000000  0.000000  ...   0.000000   0.000000
# PC                           0.000000  0.000000  ...   0.000000   0.000000
# Naive CD4+ T                 0.002613  0.000081  ...   0.000000   0.000000
# ISG+ CD4+ T                  0.000507  0.000063  ...   0.000000   0.000000
# CD4+ TCM                     0.000150  0.000000  ...   0.000000   0.000000
# CD4+ TEM                     0.000735  0.000000  ...   0.000000   0.000000
# ZBTB16+ CD4+ T               0.000000  0.002081  ...   0.000000   0.000000
# Naive Treg                   0.002142  0.000000  ...   0.000000   0.000000
# TIGIT+ Treg                  0.000753  0.000377  ...   0.000000   0.000000
# Memory Treg                  0.000000  0.000000  ...   0.000000   0.000000
# ISG+ Treg                    0.000000  0.000000  ...   0.000000   0.000000
# Naive CD8+ T                 0.873143  0.071861  ...   0.000000   0.000000
# ISG+ CD8+ T                  0.540502  0.024373  ...   0.000000   0.000000
# GZMK+ T                      0.264957  0.014530  ...   0.000000   0.000000
# CCL5+ GZMK+ T                0.187065  0.002985  ...   0.000000   0.000000
# S100+ GZMK+ T                0.010526  0.000000  ...   0.000000   0.000000
# MAIT                         0.000854  0.000000  ...   0.000000   0.000000
# Temra                        0.001888  0.000000  ...   0.000000   0.000000
# γδ T                         0.005287  0.003660  ...   0.000000   0.000000
# CD8+ γδ T                    0.004828  0.006207  ...   0.000000   0.000000
# Prolif/Cycling Cytotoxic T   0.048089  0.000000  ...   0.000000   0.000000
# Cytotoxic C8                 0.000000  0.000000  ...   0.000000   0.000000
# Prolif/Cycling T             0.234724  0.031297  ...   0.000000   0.000000
# CD16+ NK                     0.000000  0.000000  ...   0.000000   0.000000
# CD56+ NK                     0.000887  0.000000  ...   0.000000   0.000000
# Prolif/Cycling NK            0.000000  0.000000  ...   0.000000   0.000000
# CD14+ Monocyte               0.000000  0.000000  ...   0.992804   0.004677
# S100+ CD14+ Monocyte         0.000000  0.000000  ...   0.999923   0.000077
# ISG+ CD14+ Monocyte          0.000000  0.000000  ...   0.992304   0.007696
# CD163+ Monocyte              0.000000  0.000000  ...   0.998685   0.001052
# CD16+ Monocyte               0.000000  0.000000  ...   0.132904   0.866291
# ISG+ CD16+ Monocyte          0.000000  0.000000  ...   0.253799   0.746201
# Mo-DC                        0.000000  0.000000  ...   0.270202   0.000000
# cDC1                         0.000000  0.000000  ...   0.000000   0.000000
# cDC2                         0.000000  0.000000  ...   0.007595   0.000000
# AXL+ SIGLEC6+ DC             0.000000  0.000000  ...   0.000000   0.000000
# pDC                          0.000000  0.000000  ...   0.000000   0.000000
# Erythroblast                 0.034483  0.000000  ...   0.005747   0.000000
# HSC                          0.000000  0.000000  ...   0.000000   0.000000
# ILC-like                     0.000000  0.000000  ...   0.000000   0.000000
# MGK                          0.000000  0.000000  ...   0.000000   0.000000
#
#                                 cDC1      cDC2      ASDC      pDC     Eryth  \
# Naive B                     0.000000  0.000000  0.000000  0.00000  0.000000
# ISG+ B                      0.000000  0.000000  0.000000  0.00000  0.000000
# TXNIP+ B                    0.000000  0.000000  0.000000  0.00000  0.000000
# TrB                         0.000000  0.000000  0.000000  0.00000  0.000000
# ISG+ TrB                    0.000000  0.000000  0.000000  0.00000  0.000000
# Memory B                    0.000000  0.000000  0.000000  0.00000  0.000000
# AIM2+ Memory B              0.000000  0.000000  0.000000  0.00000  0.000000
# CD24- B                     0.000000  0.000000  0.000000  0.00000  0.000000
# PC                          0.000000  0.000000  0.000000  0.00000  0.000000
# Naive CD4+ T                0.000000  0.000000  0.000000  0.00000  0.000000
# ISG+ CD4+ T                 0.000000  0.000000  0.000000  0.00000  0.000000
# CD4+ TCM                    0.000000  0.000000  0.000000  0.00000  0.000000
# CD4+ TEM                    0.000000  0.000000  0.000000  0.00000  0.000000
# ZBTB16+ CD4+ T              0.000000  0.000000  0.000000  0.00000  0.000000
# Naive Treg                  0.000000  0.000000  0.000000  0.00000  0.000000
# TIGIT+ Treg                 0.000000  0.000000  0.000000  0.00000  0.000000
# Memory Treg                 0.000000  0.000000  0.000000  0.00000  0.000000
# ISG+ Treg                   0.000000  0.000000  0.000000  0.00000  0.000000
# Naive CD8+ T                0.000000  0.000000  0.000000  0.00000  0.000000
# ISG+ CD8+ T                 0.000000  0.000000  0.000000  0.00000  0.000000
# GZMK+ T                     0.000000  0.000000  0.000000  0.00000  0.000000
# CCL5+ GZMK+ T               0.000000  0.000000  0.000000  0.00000  0.000000
# S100+ GZMK+ T               0.000000  0.000000  0.000000  0.00000  0.000000
# MAIT                        0.000000  0.000000  0.000000  0.00000  0.000000
# Temra                       0.000000  0.000000  0.000000  0.00000  0.000000
# γδ T                        0.000000  0.000000  0.000000  0.00000  0.000000
# CD8+ γδ T                   0.000000  0.000000  0.000000  0.00000  0.000000
# Prolif/Cycling Cytotoxic T  0.000000  0.000000  0.000000  0.00000  0.000000
# Cytotoxic C8                0.000000  0.000000  0.000000  0.00000  0.000000
# Prolif/Cycling T            0.000000  0.000000  0.000000  0.00000  0.000000
# CD16+ NK                    0.000000  0.000000  0.000000  0.00000  0.000000
# CD56+ NK                    0.000000  0.000000  0.000000  0.00000  0.000000
# Prolif/Cycling NK           0.000000  0.000000  0.000000  0.00000  0.000000
# CD14+ Monocyte              0.000000  0.002519  0.000000  0.00000  0.000000
# S100+ CD14+ Monocyte        0.000000  0.000000  0.000000  0.00000  0.000000
# ISG+ CD14+ Monocyte         0.000000  0.000000  0.000000  0.00000  0.000000
# CD163+ Monocyte             0.000000  0.000263  0.000000  0.00000  0.000000
# CD16+ Monocyte              0.000000  0.000805  0.000000  0.00000  0.000000
# ISG+ CD16+ Monocyte         0.000000  0.000000  0.000000  0.00000  0.000000
# Mo-DC                       0.000000  0.729798  0.000000  0.00000  0.000000
# cDC1                        0.576923  0.423077  0.000000  0.00000  0.000000
# cDC2                        0.005063  0.987342  0.000000  0.00000  0.000000
# AXL+ SIGLEC6+ DC            0.000000  0.296296  0.074074  0.62963  0.000000
# pDC                         0.000000  0.000000  0.000000  1.00000  0.000000
# Erythroblast                0.000000  0.000000  0.000000  0.00000  0.695402
# HSC                         0.000000  0.000000  0.000000  0.00000  0.000000
# ILC-like                    0.000000  0.000000  0.000000  0.00000  0.000000
# MGK                         0.000000  0.000000  0.000000  0.00000  0.000000
#
#                                 HSPC       ILC  Platelet
# Naive B                     0.000000  0.000000  0.000000
# ISG+ B                      0.000000  0.000000  0.000000
# TXNIP+ B                    0.000000  0.000000  0.000000
# TrB                         0.000000  0.000000  0.000000
# ISG+ TrB                    0.000000  0.000000  0.000000
# Memory B                    0.000000  0.000000  0.000000
# AIM2+ Memory B              0.000000  0.000000  0.000000
# CD24- B                     0.000000  0.000000  0.000000
# PC                          0.000000  0.000000  0.000000
# Naive CD4+ T                0.000007  0.000015  0.000000
# ISG+ CD4+ T                 0.000000  0.000000  0.000000
# CD4+ TCM                    0.000000  0.000000  0.000000
# CD4+ TEM                    0.000000  0.000000  0.000000
# ZBTB16+ CD4+ T              0.000000  0.034956  0.000000
# Naive Treg                  0.000000  0.000000  0.000000
# TIGIT+ Treg                 0.000000  0.000377  0.000000
# Memory Treg                 0.000000  0.000000  0.000000
# ISG+ Treg                   0.000000  0.000000  0.000000
# Naive CD8+ T                0.000000  0.000025  0.000000
# ISG+ CD8+ T                 0.000000  0.000000  0.000000
# GZMK+ T                     0.000000  0.000000  0.000000
# CCL5+ GZMK+ T               0.000000  0.000000  0.000000
# S100+ GZMK+ T               0.000000  0.000000  0.000000
# MAIT                        0.000000  0.000000  0.000000
# Temra                       0.000000  0.000000  0.000000
# γδ T                        0.000407  0.000000  0.000000
# CD8+ γδ T                   0.000000  0.000000  0.000000
# Prolif/Cycling Cytotoxic T  0.000000  0.000000  0.000000
# Cytotoxic C8                0.000000  0.000000  0.000000
# Prolif/Cycling T            0.000000  0.000000  0.000000
# CD16+ NK                    0.000000  0.000000  0.000000
# CD56+ NK                    0.000000  0.027211  0.000000
# Prolif/Cycling NK           0.000000  0.000000  0.000000
# CD14+ Monocyte              0.000000  0.000000  0.000000
# S100+ CD14+ Monocyte        0.000000  0.000000  0.000000
# ISG+ CD14+ Monocyte         0.000000  0.000000  0.000000
# CD163+ Monocyte             0.000000  0.000000  0.000000
# CD16+ Monocyte              0.000000  0.000000  0.000000
# ISG+ CD16+ Monocyte         0.000000  0.000000  0.000000
# Mo-DC                       0.000000  0.000000  0.000000
# cDC1                        0.000000  0.000000  0.000000
# cDC2                        0.000000  0.000000  0.000000
# AXL+ SIGLEC6+ DC            0.000000  0.000000  0.000000
# pDC                         0.000000  0.000000  0.000000
# Erythroblast                0.000000  0.000000  0.005747
# HSC                         0.997297  0.002703  0.000000
# ILC-like                    0.000000  0.920354  0.000000
# MGK                         0.012821  0.000000  0.987179
#
# [48 rows x 29 columns]

# %%
fig = plt.figure(figsize=(12,14))
sb.heatmap(newdf, annot=False, cmap='Blues')

fig.savefig('AzimuthHeatmap.pdf', format='pdf', bbox_inches='tight')
